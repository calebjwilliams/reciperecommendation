# %% [markdown]
# # Project: Recipe Recommendation System

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('recipes.csv')
df.head()
# Out:
#                                          title total_time prep_time cook_time  \
# 0                     Air Fryer Halloumi Fries    15 mins    5 mins   10 mins
# 1         Olive-Brined Air Fryer Turkey Breast       1 hr   10 mins   40 mins
# 2                   Air Fryer Brussels Sprouts    15 mins    5 mins   10 mins
# 3  Blackberry Cobbler with Frozen Blackberries    29 mins   15 mins   14 mins
# 4           Air Fryer Cinnamon-Sugar Doughnuts    15 mins   10 mins    5 mins
#
#                                          ingredients  \
# 0  8 ounces halloumi cheese, 2 teaspoons olive oi...
# 1  1 tablespoon finely chopped fresh rosemary, 1 ...
# 2  12 , Brussels sprouts, 2 teaspoons ontreal ste...
# 3  1 sheet frozen puff pastry, thawed, 1 large eg...
# 4  flour for dusting, 1 (8 ounce) package refrige...
#
#                                       serving_info  \
# 0                                              NaN
# 1           Original recipe (1X) yields 6 servings
# 2  Original recipe (1X) yields 4 servings servings
# 3           Original recipe (1X) yields 8 servings
# 4                                              NaN
#
#                                      nutrition_facts               rating  \
# 0  {'Calories': '66', 'Fat': '6g', 'Carbs': '1g',...                  5.0
# 1  {'Calories': '263', 'Fat': '10g', 'Carbs': '0g...                  4.9
# 2  {'Calories': '203', 'Fat': '13g', 'Carbs': '6g...                  5.0
# 3  {'Calories': '211', 'Fat': '14g', 'Carbs': '19...  No rating available
# 4  {'Calories': '227', 'Fat': '16g', 'Carbs': '16...                  4.6
#
#                                          recipe_link
# 0  https://www.allrecipes.com/recipe/8462063/air-...
# 1  https://www.allrecipes.com/recipe/275372/air-f...
# 2  https://www.allrecipes.com/air-fryer-bacon-wra...
# 3  https://www.allrecipes.com/recipe/8457748/air-...
# 4  https://www.allrecipes.com/recipe/8458926/air-...

# %%
na_counts = df.isna().sum()
print(na_counts)
# Out:
# title                24
# total_time          543
# prep_time           618
# cook_time          2436
# ingredients           0
# serving_info       3311
# nutrition_facts       0
# rating                0
# recipe_link           0
# dtype: int64

# %%
# Drop rows where the ingredients column has "No ingredients listed"
df_cleaned = df[df['ingredients'] != "No ingredients listed"]

# Reset index after dropping rows (optional)
df_cleaned = df_cleaned.reset_index(drop=True)

# Display the cleaned DataFrame
df_cleaned.head()
# Out:
#                                          title total_time prep_time cook_time  \
# 0                     Air Fryer Halloumi Fries    15 mins    5 mins   10 mins
# 1         Olive-Brined Air Fryer Turkey Breast       1 hr   10 mins   40 mins
# 2                   Air Fryer Brussels Sprouts    15 mins    5 mins   10 mins
# 3  Blackberry Cobbler with Frozen Blackberries    29 mins   15 mins   14 mins
# 4           Air Fryer Cinnamon-Sugar Doughnuts    15 mins   10 mins    5 mins
#
#                                          ingredients  \
# 0  8 ounces halloumi cheese, 2 teaspoons olive oi...
# 1  1 tablespoon finely chopped fresh rosemary, 1 ...
# 2  12 , Brussels sprouts, 2 teaspoons ontreal ste...
# 3  1 sheet frozen puff pastry, thawed, 1 large eg...
# 4  flour for dusting, 1 (8 ounce) package refrige...
#
#                                       serving_info  \
# 0                                              NaN
# 1           Original recipe (1X) yields 6 servings
# 2  Original recipe (1X) yields 4 servings servings
# 3           Original recipe (1X) yields 8 servings
# 4                                              NaN
#
#                                      nutrition_facts               rating  \
# 0  {'Calories': '66', 'Fat': '6g', 'Carbs': '1g',...                  5.0
# 1  {'Calories': '263', 'Fat': '10g', 'Carbs': '0g...                  4.9
# 2  {'Calories': '203', 'Fat': '13g', 'Carbs': '6g...                  5.0
# 3  {'Calories': '211', 'Fat': '14g', 'Carbs': '19...  No rating available
# 4  {'Calories': '227', 'Fat': '16g', 'Carbs': '16...                  4.6
#
#                                          recipe_link
# 0  https://www.allrecipes.com/recipe/8462063/air-...
# 1  https://www.allrecipes.com/recipe/275372/air-f...
# 2  https://www.allrecipes.com/air-fryer-bacon-wra...
# 3  https://www.allrecipes.com/recipe/8457748/air-...
# 4  https://www.allrecipes.com/recipe/8458926/air-...

# %%
# Extract nutrition facts into separate columns
nutrition_df = df_cleaned['nutrition_facts'].apply(eval).apply(pd.Series)
nutrition_df.rename(columns=lambda x: x.lower(), inplace=True)

# Clean ingredients column to be a list
df_cleaned['ingredients'] = df_cleaned['ingredients'].str.split(', ')

# Merge the extracted nutrition facts back into the main DataFrame
df_cleaned = pd.concat([df_cleaned, nutrition_df], axis=1).drop(columns=['nutrition_facts'])

# Display the cleaned DataFrame
df_cleaned.head()
# Out:
#                                          title total_time prep_time cook_time  \
# 0                     Air Fryer Halloumi Fries    15 mins    5 mins   10 mins
# 1         Olive-Brined Air Fryer Turkey Breast       1 hr   10 mins   40 mins
# 2                   Air Fryer Brussels Sprouts    15 mins    5 mins   10 mins
# 3  Blackberry Cobbler with Frozen Blackberries    29 mins   15 mins   14 mins
# 4           Air Fryer Cinnamon-Sugar Doughnuts    15 mins   10 mins    5 mins
#
#                                          ingredients  \
# 0  [8 ounces halloumi cheese, 2 teaspoons olive o...
# 1  [1 tablespoon finely chopped fresh rosemary, 1...
# 2  [12 , Brussels sprouts, 2 teaspoons ontreal st...
# 3  [1 sheet frozen puff pastry, thawed, 1 large e...
# 4  [flour for dusting, 1 (8 ounce) package refrig...
#
#                                       serving_info               rating  \
# 0                                              NaN                  5.0
# 1           Original recipe (1X) yields 6 servings                  4.9
# 2  Original recipe (1X) yields 4 servings servings                  5.0
# 3           Original recipe (1X) yields 8 servings  No rating available
# 4                                              NaN                  4.6
#
#                                          recipe_link calories  fat carbs  \
# 0  https://www.allrecipes.com/recipe/8462063/air-...       66   6g    1g
# 1  https://www.allrecipes.com/recipe/275372/air-f...      263  10g    0g
# 2  https://www.allrecipes.com/air-fryer-bacon-wra...      203  13g    6g
# 3  https://www.allrecipes.com/recipe/8457748/air-...      211  14g   19g
# 4  https://www.allrecipes.com/recipe/8458926/air-...      227  16g   16g
#
#   protein
# 0      4g
# 1     40g
# 2     17g
# 3      3g
# 4      5g

# %%
# Extract the numeric value only if it exists, ignoring NaN
df_cleaned['serving_info'] = df_cleaned['serving_info'].dropna().str.extract(r'yields (\d+)(?: servings)?')

# Convert to integer only for non-NaN values
df_cleaned['serving_info'] = pd.to_numeric(df_cleaned['serving_info'], errors='coerce')

# Display the resulting DataFrame
df_cleaned.head()
# Out:
#                                          title total_time prep_time cook_time  \
# 0                     Air Fryer Halloumi Fries    15 mins    5 mins   10 mins
# 1         Olive-Brined Air Fryer Turkey Breast       1 hr   10 mins   40 mins
# 2                   Air Fryer Brussels Sprouts    15 mins    5 mins   10 mins
# 3  Blackberry Cobbler with Frozen Blackberries    29 mins   15 mins   14 mins
# 4           Air Fryer Cinnamon-Sugar Doughnuts    15 mins   10 mins    5 mins
#
#                                          ingredients  serving_info  \
# 0  [8 ounces halloumi cheese, 2 teaspoons olive o...           NaN
# 1  [1 tablespoon finely chopped fresh rosemary, 1...           6.0
# 2  [12 , Brussels sprouts, 2 teaspoons ontreal st...           4.0
# 3  [1 sheet frozen puff pastry, thawed, 1 large e...           8.0
# 4  [flour for dusting, 1 (8 ounce) package refrig...           NaN
#
#                 rating                                        recipe_link  \
# 0                  5.0  https://www.allrecipes.com/recipe/8462063/air-...
# 1                  4.9  https://www.allrecipes.com/recipe/275372/air-f...
# 2                  5.0  https://www.allrecipes.com/air-fryer-bacon-wra...
# 3  No rating available  https://www.allrecipes.com/recipe/8457748/air-...
# 4                  4.6  https://www.allrecipes.com/recipe/8458926/air-...
#
#   calories  fat carbs protein
# 0       66   6g    1g      4g
# 1      263  10g    0g     40g
# 2      203  13g    6g     17g
# 3      211  14g   19g      3g
# 4      227  16g   16g      5g

# %%
# Replace "No rating available" with NaN
df_cleaned['rating'] = df_cleaned['rating'].replace("No rating available", np.nan)

df_cleaned.head()
# Out:
#                                          title total_time prep_time cook_time  \
# 0                     Air Fryer Halloumi Fries    15 mins    5 mins   10 mins
# 1         Olive-Brined Air Fryer Turkey Breast       1 hr   10 mins   40 mins
# 2                   Air Fryer Brussels Sprouts    15 mins    5 mins   10 mins
# 3  Blackberry Cobbler with Frozen Blackberries    29 mins   15 mins   14 mins
# 4           Air Fryer Cinnamon-Sugar Doughnuts    15 mins   10 mins    5 mins
#
#                                          ingredients  serving_info rating  \
# 0  [8 ounces halloumi cheese, 2 teaspoons olive o...           NaN    5.0
# 1  [1 tablespoon finely chopped fresh rosemary, 1...           6.0    4.9
# 2  [12 , Brussels sprouts, 2 teaspoons ontreal st...           4.0    5.0
# 3  [1 sheet frozen puff pastry, thawed, 1 large e...           8.0    NaN
# 4  [flour for dusting, 1 (8 ounce) package refrig...           NaN    4.6
#
#                                          recipe_link calories  fat carbs  \
# 0  https://www.allrecipes.com/recipe/8462063/air-...       66   6g    1g
# 1  https://www.allrecipes.com/recipe/275372/air-f...      263  10g    0g
# 2  https://www.allrecipes.com/air-fryer-bacon-wra...      203  13g    6g
# 3  https://www.allrecipes.com/recipe/8457748/air-...      211  14g   19g
# 4  https://www.allrecipes.com/recipe/8458926/air-...      227  16g   16g
#
#   protein
# 0      4g
# 1     40g
# 2     17g
# 3      3g
# 4      5g

# %%
df_cleaned.to_csv('recipes_cleaned.csv', index = False)
