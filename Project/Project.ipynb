# %% [markdown]
# # Project: Recipe Recommendation System

# %%
import pandas as pd

df = pd.read_csv('recipes_database.csv')

# %%
df
# Out:
#                                              title       total_time prep_time  \
# 0                         Air Fryer Halloumi Fries          15 mins    5 mins
# 1             Olive-Brined Air Fryer Turkey Breast             1 hr   10 mins
# 2                       Air Fryer Brussels Sprouts          15 mins    5 mins
# 3      Blackberry Cobbler with Frozen Blackberries          29 mins   15 mins
# 4               Air Fryer Cinnamon-Sugar Doughnuts          15 mins   10 mins
# ...                                            ...              ...       ...
# 14124               Cinnamon-Apple Bars with Icing      1 hr 5 mins   20 mins
# 14125                            Oreo® Cookie Bars     4 hrs 5 mins   25 mins
# 14126               Cinnamon-Apple Bars with Icing     1 hr 40 mins   20 mins
# 14127           Ricotta Pineapple Upside-Down Cake     1 hr 20 mins   20 mins
# 14128                                    Borscht I   10 hrs 40 mins   30 mins
#
# ...
